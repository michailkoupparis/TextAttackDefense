# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/TryTextAttackAgain
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/TryTextAttackAgain'
# /content/drive/.shortcut-targets-by-id/1xVZvo91E52ht1jzemVDt-mKblsI1s5-z/TryTextAttackAgain/TextAttack

# %%
# !ls
# Out:
# '=0.16.0'	    docs	 README.md	    textattack
#  build		    examples	 requirements.txt   textattack.egg-info
#  CONTRIBUTING.md    LICENSE	 setup.cfg	    wandb
#  date_now-log.txt   Makefile	 setup.py
#  dist		    pytest.ini	 tests

# %%
#!git clone https://github.com/QData/TextAttack.git

# %%
# %cd TextAttack/
# Out:
# [Errno 2] No such file or directory: 'TextAttack/'
# /content/drive/.shortcut-targets-by-id/1xVZvo91E52ht1jzemVDt-mKblsI1s5-z/TryTextAttackAgain/TextAttack

# %%
#!pip install pyarrow==0.16.0 --force-reinstall
# !python3 setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing textattack.egg-info/PKG-INFO
# writing dependency_links to textattack.egg-info/dependency_links.txt
# writing entry points to textattack.egg-info/entry_points.txt
# writing requirements to textattack.egg-info/requires.txt
# writing top-level names to textattack.egg-info/top_level.txt
# writing manifest file 'textattack.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/textattack
# copying build/lib/textattack/__main__.py -> build/bdist.linux-x86_64/egg/textattack
# copying build/lib/textattack/__init__.py -> build/bdist.linux-x86_64/egg/textattack
# creating build/bdist.linux-x86_64/egg/textattack/attack_recipes
# copying build/lib/textattack/attack_recipes/bae_garg_2019.py -> build/bdist.linux-x86_64/egg/textattack/attack_recipes
# ...

# %%
# !ls
# Out:
# '=0.16.0'	    docs	 README.md	    textattack
#  build		    examples	 requirements.txt   textattack.egg-info
#  CONTRIBUTING.md    LICENSE	 setup.cfg	    wandb
#  date_now-log.txt   Makefile	 setup.py
#  dist		    pytest.ini	 tests

# %% [markdown]
# #Training

# %% [markdown]
# # Try textattack/bert-base-uncased-mnli

# %%
# !textattack train --lr 3e-5 --model textattack/bert-base-uncased-MNLI  --dataset multi_nli --max-length 128 --batch-size 64 --epochs 5 --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
# Out:
# 2020-08-25 12:50:33.097710: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: WARNING: TextAttack's model training feature is in beta. Please report any issues on our Github page, https://github.com/QData/TextAttack/issues.
# textattack: Writing logs to ../TrainedBertModels/outputs/training/textattack/bert-base-uncased-MNLI-multi_nli-2020-08-25-12-50-35-717244/log.txt.
# ...
# Dataset multi_nli downloaded and prepared to /root/.cache/huggingface/datasets/multi_nli/plain_text/1.0.0/60774175381b9f3f1e6ae1028229e3cdb270d50379f45b9f2c01008f50f09e6b. Subsequent calls will reuse this data.
# textattack: Loading nlp dataset multi_nli, split train.
# ----MANUALLY CREATING EVAL DATASET USING : 58906
#
# ----Train Indices : 333796
#
# ----Eval Indices : 58906
#
# ...

# %%
# !textattack eval --model-from-huggingface ../TrainedBertModels/outputs/training/textattack/bert-base-uncased-MNLI-multi_nli-2020-08-25-12-50-35-717244/ --dataset-from-nlp multi_nli --dataset_split validation_mismatched --num-examples 10000
# Out:
# 2020-08-25 18:26:46.338453: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: Loading pre-trained model from HuggingFace model repository: ../TrainedBertModels/outputs/training/textattack/bert-base-uncased-MNLI-multi_nli-2020-08-25-12-50-35-717244/
# textattack: Loading nlp dataset multi_nli, split validation_mismatched.
# textattack: Got 9832 predictions.
# textattack: Successes 8252/9832 (83.93%)

# %%
# !textattack eval --model-from-huggingface ../TrainedBertModels/outputs/training/textattack/bert-base-uncased-MNLI-multi_nli-2020-08-25-12-50-35-717244/ --dataset-from-nlp multi_nli --dataset_split validation_matched --num-examples 10000
# Out:
# 2020-08-25 18:28:16.611068: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: Loading pre-trained model from HuggingFace model repository: ../TrainedBertModels/outputs/training/textattack/bert-base-uncased-MNLI-multi_nli-2020-08-25-12-50-35-717244/
# textattack: Loading nlp dataset multi_nli, split validation_matched.
# textattack: Got 9815 predictions.
# textattack: Successes 8230/9815 (83.85%)

# %% [markdown]
# # Try bert-based-uncased

# %%
# !textattack train --lr 3e-5 --model  bert-base-uncased  --dataset multi_nli --max-length 128 --batch-size 64 --epochs 5 --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
# Out:
# textattack: First time running textattack: downloading remaining required packages.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2020-08-26 04:35:43.826288: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# ...

# %% [markdown]
# # aloxatel/bert-base-mnli

# %%
# !textattack train --lr 3e-5 --model aloxatel/bert-base-mnli  --dataset multi_nli --max-length 256 --batch-size 32 --epochs 4 --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
