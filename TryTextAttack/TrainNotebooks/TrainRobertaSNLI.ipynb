# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive/TryTextAttackAgain
# Out:
# BaseLoading.ipynb				  multi_nli_train_word_freq.csv
# corpus.py					  preprocess_datasets
# DefendBertGuide.ipynb				  prioritized.py
# detect_adversarial.py				  __pycache__
# EvalBert.ipynb					  RunFull
# freq_attacks_mnli.py				  snli_train_word_freq.csv
# freq_attacks_snli.py				  TextAttack
# freq_stats.py					  TrainedBertModels
# InferSent.ipynb					  TrainNotebooks
# inferSentModel.py				  wandb
# InferSent_snli_pretrained_GLOVEepoch10.fullmodel

# %%
# %cd drive/My\ Drive/TryTextAttackAgain
# Out:
# /content/drive/.shortcut-targets-by-id/1xVZvo91E52ht1jzemVDt-mKblsI1s5-z/TryTextAttackAgain

# %%
# !ls
# Out:
# BaseLoading.ipynb				  multi_nli_train_word_freq.csv
# corpus.py					  preprocess_datasets
# DefendBertGuide.ipynb				  prioritized.py
# detect_adversarial.py				  __pycache__
# EvalBert.ipynb					  RunFull
# freq_attacks_mnli.py				  snli_train_word_freq.csv
# freq_attacks_snli.py				  TextAttack
# freq_stats.py					  TrainedBertModels
# InferSent.ipynb					  TrainNotebooks
# inferSentModel.py				  wandb
# InferSent_snli_pretrained_GLOVEepoch10.fullmodel

# %%
#!git clone https://github.com/QData/TextAttack.git

# %%
# %cd TextAttack/
# Out:
# /content/drive/.shortcut-targets-by-id/1xVZvo91E52ht1jzemVDt-mKblsI1s5-z/TryTextAttackAgain/TextAttack

# %%
# !pip install pyarrow>=0.16.0 --force-reinstall
# !python3 setup.py install
# Out:
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: textattack 0.2.4 has requirement numpy<1.19.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: flair 0.6 has requirement pytest>=5.3.2, but you'll have pytest 3.6.4 which is incompatible.
# running install
# running bdist_egg
# running egg_info
# writing textattack.egg-info/PKG-INFO
# writing dependency_links to textattack.egg-info/dependency_links.txt
# writing entry points to textattack.egg-info/entry_points.txt
# writing requirements to textattack.egg-info/requires.txt
# writing top-level names to textattack.egg-info/top_level.txt
# writing manifest file 'textattack.egg-info/SOURCES.txt'
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.9.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.2.10
# astor                         0.8.1
# astropy                       4.0.1.post1
# astunparse                    1.6.3
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         19.3.0
# audioread                     2.1.8
# autograd                      1.3
# Babel                         2.8.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bert-score                    0.3.5
# bleach                        3.1.5
# blis                          0.4.1
# bokeh                         2.1.1
# boto                          2.49.0
# boto3                         1.14.37
# ...

# %%
# !textattack train --model lstm --dataset snli --epochs 2 --allowed-labels 0 1 2 --batch-size 16 --max-length 128
# Out:
# 2020-08-25 09:39:52.772334: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: WARNING: TextAttack's model training feature is in beta. Please report any issues on our Github page, https://github.com/QData/TextAttack/issues.
# textattack: Writing logs to /usr/local/lib/python3.6/dist-packages/textattack-0.2.4-py3.6.egg/outputs/training/lstm-snli-2020-08-25-09-39-56-180557/log.txt.
# textattack: Loading nlp dataset snli, split train.
# textattack: Loading nlp dataset snli, split validation.
# ----NUMBER OF EVAL LALBELS---
# 10000
# textattack: Loaded dataset. Found: 3 labels: [0, 1, 2]
# textattack: Loading textattack model: LSTMForClassification
# textattack: Training model across 1 GPUs
# ...

# %%
# Out:
# [('a', 'b', 'c', 'd'), (1, 2, 3, 4)]

# %%
a = list(zip(*a))
# Out:
# [('dsjfjds', 'sjhsahjd', 'hshsa, sjaj'),
#  ('sdhhdsb  sahd', 'klous saju .', 'shajsj j')]

# %%
list(zip([1,3,5,32],[9,7,4,2]))
# Out:
# [(1, 9), (3, 7), (5, 4), (32, 2)]

# %%
# !ls
# Out:
# '=0.16.0'	    docs	 README.md	    textattack
#  build		    examples	 requirements.txt   textattack.egg-info
#  CONTRIBUTING.md    LICENSE	 setup.cfg	    wandb
#  date_now-log.txt   Makefile	 setup.py
#  dist		    pytest.ini	 tests

# %%
# !textattack eval --model  /usr/local/lib/python3.6/dist-packages/textattack-0.2.4-py3.6.egg/outputs/training/lstm-imdb-2020-08-25-06-45-50-600825/ --dataset-from-nlp imdb
# Out:
# 2020-08-25 06:48:15.791010: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: Loading textattack model: LSTMForClassification
# textattack: Loading nlp dataset imdb, split test.
# textattack: Got 5 predictions.
# textattack: Successes 2/5 (40.00%)

# %% [markdown]
# # Learning rate 5e5 batch size 32 epochs 4 max length 128

# %%
#!textattack train --lr 5e-5 --max-length 128 --batch-size 32 --epochs 4  --model roberta-base --dataset snli --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
# Out:
# textattack: First time running textattack: downloading remaining required packages.
# textattack: Downloading NLTK required packages.
# Traceback (most recent call last):
#   File "/usr/local/bin/textattack", line 33, in <module>
#     sys.exit(load_entry_point('textattack==0.2.4', 'console_scripts', 'textattack')())
#   File "/usr/local/bin/textattack", line 25, in importlib_load_entry_point
#     return next(matches).load()
#   File "/usr/local/lib/python3.6/dist-packages/importlib_metadata/__init__.py", line 105, in load
#     module = import_module(match.group('module'))
#   File "/usr/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
# ...

# %%
# !ls ../TrainedBertModels/
# Out:
# bert-base-uncased-snli	outputs

# %% [markdown]
# # Same batch size 64

# %%
#!textattack train --lr 5e-5 --max-length 128 --batch-size 64 --epochs 4  --model roberta-base --dataset snli --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
# Out:
# textattack: First time running textattack: downloading remaining required packages.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2020-08-23 10:37:51.580543: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# ...

# %%
# !textattack train --lr 3e-5 --max-length 128 --batch-size 32 --epochs 4  --model roberta-base --dataset snli --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
# Out:
# textattack: First time running textattack: downloading remaining required packages.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2020-08-24 14:37:15.053202: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# ...

# %%
# !textattack train --lr 3e-5 --max-length 64 --batch-size 32 --epochs 4  --model roberta-base --dataset snli --allowed-labels 0 1 2 --output_dir ../TrainedBertModels/
