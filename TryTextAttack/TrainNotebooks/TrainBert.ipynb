# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/TryTextAttackAgain
# Out:
# /content/drive/My Drive/TryTextAttackAgain

# %%
# !ls
# Out:
# EvalBert.ipynb	     snliData	 TrainBert.ipynb
# preprocess_datasets  TextAttack  TrainedBertModels

# %%
#!git clone https://github.com/QData/TextAttack.git

# %%
# %cd TextAttack/
# Out:
# /content/drive/My Drive/TryTextAttackAgain/TextAttack

# %%
#!pip install pyarrow==0.16.0 --force-reinstall
# !python3 setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing textattack.egg-info/PKG-INFO
# writing dependency_links to textattack.egg-info/dependency_links.txt
# writing entry points to textattack.egg-info/entry_points.txt
# writing requirements to textattack.egg-info/requires.txt
# writing top-level names to textattack.egg-info/top_level.txt
# package init file 'TrainedBertModels/__init__.py' not found (or not a regular file)
# package init file 'TrainedLSTM/__init__.py' not found (or not a regular file)
# package init file 'TrainedCNN/__init__.py' not found (or not a regular file)
# package init file 'TrainedBertModels/outputs/__init__.py' not found (or not a regular file)
# package init file 'TrainedBertModels/outputs/training/__init__.py' not found (or not a regular file)
# package init file 'TrainedBertModels/outputs/training/bert-base-uncased-snli-lr5e5_batchsize64_maxlength128/__init__.py' not found (or not a regular file)
# ...

# %%
# !ls
# Out:
# '=0.16.0'	    docs	 README.md	    textattack		  wandb
#  build		    examples	 requirements.txt   textattack.egg-info
#  CONTRIBUTING.md    LICENSE	 setup.cfg	    TrainedBertModels
#  date_now-log.txt   Makefile	 setup.py	    TrainedCNN
#  dist		    pytest.ini	 tests		    TrainedLSTM

# %% [markdown]
# #Training

# %%
'''
function ClickConnect(){
    console.log("Working"); 
    document.querySelector("colab-toolbar-button#connect").click() 
    # or document.querySelector("colab-connect-button").click()
}
var myTimer = setInterval(ClickConnect,180000);
clearInterval(myTimer);
'''
#CLick to prevent diconnection (cmd alt k on firefox to reach cosole)

'''
from pyautogui import press, typewrite, hotkey
import time
from random import shuffle

array = ["left", "right", "up", "down"]

while True:
    shuffle(array)
    time.sleep(10)
    press(array[0])
    press(array[1])
    press(array[2])
    press(array[3])
'''
# Out:
# '\nfrom pyautogui import press, typewrite, hotkey\nimport time\nfrom random import shuffle\n\narray = ["left", "right", "up", "down"]\n\nwhile True:\n    shuffle(array)\n    time.sleep(10)\n    press(array[0])\n    press(array[1])\n    press(array[2])\n    press(array[3])\n'

# %% [markdown]
# # Max Length 64 Learning rate 5e-5, batch_size 32

# %%
#!textattack train --lr 5e-5 --max-length 64 --batch-size 32 --epochs 4  --model bert-base-uncased --dataset snli --allowed-labels 0 1 2 --output_dir TrainedBertModels/

# %% [markdown]
# # Learning rate 5e-5, batch_size 64

# %%
#!textattack train --lr 5e-5 --model bert-base-uncased --dataset snli --max-length 64 --batch-size 64 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/

# %% [markdown]
# # Learning rate 1e-5 batch size 32

# %%
#!textattack train --lr 1e-5 --model bert-base-uncased --dataset snli --max-length 64 --batch-size 32 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/

# %% [markdown]
# #Learning rate 1e-5, batch_size 64

# %%
#!textattack train --lr 1e-5 --model bert-base-uncased --dataset snli --max-length 64 --batch-size 64 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/
# Out:
# textattack: First time running textattack: downloading remaining required packages.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2020-08-14 20:41:03.262475: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# ...

# %% [markdown]
# #Learning rate 3e-5, batch_size 32

# %%
# !textattack train --lr 3e-5 --model bert-base-uncased --dataset snli --max-length 64 --batch-size 32 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/
# Out:
# 2020-08-14 23:45:17.781124: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: WARNING: TextAttack's model training feature is in beta. Please report any issues on our Github page, https://github.com/QData/TextAttack/issues.
# textattack: Writing logs to TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-14-23-45-21-686868/log.txt.
# textattack: Loading nlp dataset snli, split train.
# textattack: Loading nlp dataset snli, split validation.
# textattack: Loaded dataset. Found: 3 labels: [0, 1, 2]
# textattack: Loading transformers AutoModelForSequenceClassification: bert-base-uncased
# ...

# %% [markdown]
# # #Learning rate 3e-5, batch_size 64

# %%
#!textattack train --lr 3e-5 --model bert-base-uncased --dataset snli --max-length 64 --batch-size 64 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/
# Out:
# 2020-08-13 18:22:30.197399: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: WARNING: TextAttack's model training feature is in beta. Please report any issues on our Github page, https://github.com/QData/TextAttack/issues.
# textattack: Writing logs to TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-13-18-22-36-965151/log.txt.
# textattack: Loading nlp dataset snli, split train.
# textattack: Loading nlp dataset snli, split validation.
# textattack: Loaded dataset. Found: 3 labels: [0, 1, 2]
# textattack: Loading transformers AutoModelForSequenceClassification: bert-base-uncased
# ...

# %%
#!textattack attack --recipe textfooler --num-examples 1000 --dataset-from-nlp snli --model-from-huggingface TrainedBertModels/outputs/training/distilbert-base-cased-snli-2020-08-11-18-29-59-220038
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [Succeeded / Failed / Total] 381 / 12 / 471:  47% 471/1000 [01:54<02:08,  4.11it/s]--------------------------------------------- Result 472 ---------------------------------------------
# Entailment (97%) --> Neutral (53%)
#
# Premise: A person in a pink knitted hat and brightly colored shirt is playing the trumpet as part of a brass band, although only parts of two other instruments are visible.
# Hypothesis: The person is playing a musical instrument.
#
# Premise: A person in a pink knitted hat and brightly colored shirt is playing the trumpet as part of a brass band, although only parts of two other instruments are visible.
# Hypothesis: The person is playing a musical paraphernalia.
#
#
# [Succeeded / Failed / Total] 382 / 12 / 472:  47% 472/1000 [01:54<02:08,  4.11it/s]--------------------------------------------- Result 473 ---------------------------------------------
# Neutral (94%) --> [FAILED]
#
# ...
