# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/TryTextAttackAgain
# Out:
# /content/drive/My Drive/TryTextAttackAgain

# %%
# !ls
# Out:
# BasinLoading.ipynb  EvalBert.ipynb	 snliData    TrainBert.ipynb
# DefendBert.ipynb    preprocess_datasets  TextAttack  TrainedBertModels

# %%
#!git clone https://github.com/QData/TextAttack.git

# %%
# %cd TextAttack/
# Out:
# /content/drive/My Drive/TryTextAttackAgain/TextAttack

# %%
# !pip install pyarrow>=0.16.0 --force-reinstall
# !python3 setup.py install
# Out:
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: textattack 0.2.4 has requirement numpy<1.19.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: flair 0.5.1 has requirement pytest>=5.3.2, but you'll have pytest 3.6.4 which is incompatible.
# running install
# running bdist_egg
# running egg_info
# writing textattack.egg-info/PKG-INFO
# writing dependency_links to textattack.egg-info/dependency_links.txt
# writing entry points to textattack.egg-info/entry_points.txt
# writing requirements to textattack.egg-info/requires.txt
# writing top-level names to textattack.egg-info/top_level.txt
# package init file 'TrainedBertModels/__init__.py' not found (or not a regular file)
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.9.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.2.10
# astor                         0.8.1
# astropy                       4.0.1.post1
# astunparse                    1.6.3
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         19.3.0
# audioread                     2.1.8
# autograd                      1.3
# Babel                         2.8.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bert-score                    0.3.5
# bleach                        3.1.5
# blis                          0.4.1
# bokeh                         2.1.1
# boto                          2.49.0
# boto3                         1.14.37
# ...

# %%
#!ls TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %% [markdown]
# # Check Maximum Length of Train, Test, Eval to set maximum sequence length
#
# and create csv files

# %%
'''
# Check Maximum Length of Train, Test, Eval 
import os
import numpy as np
import pandas as pd

def get_length(dictionary,prem,hypo):

  label1_lengths = np.array([len(sentence.split()) for sentence in dictionary[prem]])
  label2_lengths = np.array([len(sentence.split()) for sentence in dictionary[hypo]])
  all_lengths = {'prem':label1_lengths, 'hypo':label2_lengths, 'together':label1_lengths+label2_lengths}
  return all_lengths
'''
# Out:
# "\n# Check Maximum Length of Train, Test, Eval \nimport os\nimport numpy as np\nimport pandas as pd\n\ndef get_length(dictionary,prem,hypo):\n\n  label1_lengths = np.array([len(sentence.split()) for sentence in dictionary[prem]])\n  label2_lengths = np.array([len(sentence.split()) for sentence in dictionary[hypo]])\n  all_lengths = {'prem':label1_lengths, 'hypo':label2_lengths, 'together':label1_lengths+label2_lengths}\n  return all_lengths\n"

# %%
'''
import nlp

def make_nli_dictionaries_from_nlp_snli(dataset):

  dictionary = {'premise':dataset['premise'],'hypothesis':dataset['hypothesis'],'label':dataset['label']}
  
  return dictionary
'''
# Out:
# "\nimport nlp\n\ndef make_nli_dictionaries_from_nlp_snli(dataset):\n\n  dictionary = {'premise':dataset['premise'],'hypothesis':dataset['hypothesis'],'label':dataset['label']}\n  \n  return dictionary\n"

# %%
#!ls ../

# %%
'''
import pandas as pd
dataset_ = nlp.load_dataset("snli")
dt_tain = make_nli_dictionaries_from_nlp_snli(dataset_['train'])
dt_dev = make_nli_dictionaries_from_nlp_snli(dataset_['validation'])
dt_test = make_nli_dictionaries_from_nlp_snli(dataset_['test'])
dt_tain = get_length(dt_tain,'premise','hypothesis')
dt_dev = get_length(dt_dev,'premise','hypothesis')
comb_dict = {}
for key in dt_tain:
  comb_dict[key] = np.concatenate((dt_tain[key],dt_dev[key]))

length_data = pd.DataFrame.from_dict(comb_dict)

#length_data.describe()
#'''

#pd.DataFrame.from_dict(dt_tain).to_csv('../snli_train_full.csv')
#pd.DataFrame.from_dict(dt_dev).to_csv('../snli_valid_full.csv')
#pd.DataFrame.from_dict(dt_test).to_csv('../snli_test_full.csv')
# Out:
# '\nimport pandas as pd\ndataset_ = nlp.load_dataset("snli")\ndt_tain = make_nli_dictionaries_from_nlp_snli(dataset_[\'train\'])\ndt_dev = make_nli_dictionaries_from_nlp_snli(dataset_[\'validation\'])\ndt_test = make_nli_dictionaries_from_nlp_snli(dataset_[\'test\'])\ndt_tain = get_length(dt_tain,\'premise\',\'hypothesis\')\ndt_dev = get_length(dt_dev,\'premise\',\'hypothesis\')\ncomb_dict = {}\nfor key in dt_tain:\n  comb_dict[key] = np.concatenate((dt_tain[key],dt_dev[key]))\n\nlength_data = pd.DataFrame.from_dict(comb_dict)\n\n#length_data.describe()\n#'

# %%
'''
dataset_ = nlp.load_dataset("snli")
dt_tain = make_nli_dictionaries_from_nlp_snli(dataset_['train'])
dt_dev = make_nli_dictionaries_from_nlp_snli(dataset_['validation'])
comb_dict = {}
for key in dt_tain:
  comb_dict[key] = np.concatenate((dt_tain[key],dt_dev[key]))

length_data = pd.DataFrame.from_dict(comb_dict)

length_data.describe()
'''
# Out:
# '\ndataset_ = nlp.load_dataset("snli")\ndt_tain = make_nli_dictionaries_from_nlp_snli(dataset_[\'train\'])\ndt_dev = make_nli_dictionaries_from_nlp_snli(dataset_[\'validation\'])\ncomb_dict = {}\nfor key in dt_tain:\n  comb_dict[key] = np.concatenate((dt_tain[key],dt_dev[key]))\n\nlength_data = pd.DataFrame.from_dict(comb_dict)\n\nlength_data.describe()\n'

# %%
'''
print('Train Data ' + str(len(dataset_['train']))+ "\n")
print('Validation Data ' + str(len(dataset_['validation']))+ "\n")
'''
# Out:
# '\nprint(\'Train Data \' + str(len(dataset_[\'train\']))+ "\n")\nprint(\'Validation Data \' + str(len(dataset_[\'validation\']))+ "\n")\n'

# %%
'''
def get_nli(data_path):
    s1 = {}
    s2 = {}
    target = {}

    dico_label = {'entailment': 0,  'neutral': 1, 'contradiction': 2}

    for data_type in ['train', 'dev', 'test']:
        s1[data_type], s2[data_type], target[data_type] = {}, {}, {}
        s1[data_type]['path'] = os.path.join(data_path, 's1.' + data_type)
        s2[data_type]['path'] = os.path.join(data_path, 's2.' + data_type)
        target[data_type]['path'] = os.path.join(data_path,
                                                 'labels.' + data_type)

        s1[data_type]['sent'] = [line.rstrip() for line in
                                 open(s1[data_type]['path'], 'r')]
        s2[data_type]['sent'] = [line.rstrip() for line in
                                 open(s2[data_type]['path'], 'r')]
        target[data_type]['data'] = np.array([dico_label[line.rstrip('\n')]
                for line in open(target[data_type]['path'], 'r')])

        assert len(s1[data_type]['sent']) == len(s2[data_type]['sent']) == \
            len(target[data_type]['data'])

        print('** {0} DATA : Found {1} pairs of {2} sentences.'.format(
                data_type.upper(), len(s1[data_type]['sent']), data_type))

    train = {'s1': s1['train']['sent'], 's2': s2['train']['sent'],
             'label': target['train']['data']}
    dev = {'s1': s1['dev']['sent'], 's2': s2['dev']['sent'],
           'label': target['dev']['data']}
    test = {'s1': s1['test']['sent'], 's2': s2['test']['sent'],
            'label': target['test']['data']}
    return train, dev, test

tain_snli, dev_snli, test_snli = get_nli("../preprocess_datasets/SNLI")
train_dict = get_length(tain_snli,'s1','s2')
valid_dict = get_length(dev_snli,'s1','s2')

comb_dict = {}
for key in train_dict:
  comb_dict[key] = np.concatenate((train_dict[key],valid_dict[key]))

length_data = pd.DataFrame.from_dict(comb_dict)

length_data.describe()
'''
# Out:
# '\ndef get_nli(data_path):\n    s1 = {}\n    s2 = {}\n    target = {}\n\n    dico_label = {\'entailment\': 0,  \'neutral\': 1, \'contradiction\': 2}\n\n    for data_type in [\'train\', \'dev\', \'test\']:\n        s1[data_type], s2[data_type], target[data_type] = {}, {}, {}\n        s1[data_type][\'path\'] = os.path.join(data_path, \'s1.\' + data_type)\n        s2[data_type][\'path\'] = os.path.join(data_path, \'s2.\' + data_type)\n        target[data_type][\'path\'] = os.path.join(data_path,\n                                                 \'labels.\' + data_type)\n\n        s1[data_type][\'sent\'] = [line.rstrip() for line in\n                                 open(s1[data_type][\'path\'], \'r\')]\n        s2[data_type][\'sent\'] = [line.rstrip() for line in\n                                 open(s2[data_type][\'path\'], \'r\')]\n        target[data_type][\'data\'] = np.array([dico_label[line.rstrip(\'\n\')]\n                for line in open(target[data_type][\'path\'], \'r\')])\n\
# ...

# %% [markdown]
# #Try pwws for snli

# %%
#!textattack attack --recipe pwws --num-examples 1 --dataset-from-nlp snli  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe pwws_snli --num-examples 1 --dataset-from-nlp snli  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701 --attack_output_snli TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %% [markdown]
# # Try azalnot with different language model

# %%
#!textattack attack --recipe alzantot --num-examples 1 --dataset-from-nlp snli  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe alzantot_gpt2 --num-examples 1 --dataset-from-nlp snli  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %% [markdown]
# #Eval

# %%
#!textattack eval --num-examples 9842 --dataset_split test --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack eval --num-examples 9842 --dataset_split validation --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack eval --num-examples 10000 --dataset_split train --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %% [markdown]
# # Try attacks Output File

# %%
#!textattack attack  --recipe textfooler --num-examples 500 --dataset-from-nlp snli --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701 --attack_output_snli TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack  --recipe iga --num-examples 500 --dataset-from-nlp snli --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701 --attack_output_snli TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!ls TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack

# %%
'''
def get_texts_labels(df):
  text = []
  labels = []
  for index, row in df.iterrows():
    text.append((row['premise'],row['hypothesis']))
    labels.append(row['label'])

  return text, labels
  
import pandas as pd
#import nlp
#to_labels = nlp.features.ClassLabel(names=["entailment", "neutral", "contradiction"])
#to_labels.encode_example("contradiction")

data = pd.read_csv("TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/textfooler_10_attacked.csv", usecols=["premise", "hypothesis", "label"],) 
data['label'] = data["label"].map(lambda x: x if type(x)!=str else x.lower())
#data['label'] = data["label"].map(lambda x: to_labels.encode_example(x))

# Preview the first 5 lines of the loaded data 
print(data.head())

text, labels = get_texts_labels(data)
'''
# Out:
# '\ndef get_texts_labels(df):\n  text = []\n  labels = []\n  for index, row in df.iterrows():\n    text.append((row[\'premise\'],row[\'hypothesis\']))\n    labels.append(row[\'label\'])\n\n  return text, labels\n  \nimport pandas as pd\n#import nlp\n#to_labels = nlp.features.ClassLabel(names=["entailment", "neutral", "contradiction"])\n#to_labels.encode_example("contradiction")\n\ndata = pd.read_csv("TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/textfooler_10_attacked.csv", usecols=["premise", "hypothesis", "label"],) \ndata[\'label\'] = data["label"].map(lambda x: x if type(x)!=str else x.lower())\n#data[\'label\'] = data["label"].map(lambda x: to_labels.encode_example(x))\n\n# Preview the first 5 lines of the loaded data \nprint(data.head())\n\ntext, labels = get_texts_labels(data)\n'

# %%
#from nlp import Dataset, load_dataset
#dataset = load_dataset('csv',features=nlp.features.ClassLabel(names=["entailment", "neutral", "contradiction"]),data_files='TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/textfooler_500_original.csv')["train"]
#dataset = Dataset.from_pandas(data)
#dataset_ = nlp.load_dataset("snli")["train"]

# %%
#!textattack eval --num-examples 10 --shuffle False --dataset_split test --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %% [markdown]
# # Try eval from file

# %%
#!textattack eval --num-examples 500 --shuffle False --from_snli_attak_file  TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/textfooler_500_original.csv  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack eval --num-examples 500 --shuffle False --from_snli_attak_file  TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/textfooler_500_attacked.csv  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack eval --num-examples 500 --shuffle False --from_snli_attak_file  TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/iga_500_original.csv  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack eval --num-examples 500 --shuffle False --from_snli_attak_file  TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701/attack/iga_500_attacked.csv  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe textfooler --num-examples 500 --dataset-from-nlp snli --attack_output_snli TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe iga --num-examples 500 --dataset-from-nlp snli --attack_output_snli TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe faster-alzantot --num-examples 10 --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe alzantot --num-examples 1 --dataset-from-nlp snli  --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe iga --num-examples 1 --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack attack --recipe pwws --num-examples 1 --dataset-from-nlp snli   --model-from-huggingface TrainedBertModels/outputs/training/bert-base-uncased-snli-2020-08-11-19-36-10-587701

# %%
#!textattack train --lr 3e-5 --model bert-base-uncased --dataset snli --max-length 128 --batch-size 64 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/

# %% [markdown]
# # Try to train,attack,eval lstm for classification

# %%
#!ls TrainedLSTM/outputs/training/lstm-imdb-2020-08-13-21-25-20-085069/

# %%
#!textattack train --model lstm --dataset imdb --max-length 128 --batch-size 64 --epochs 5 --allowed-labels 0 1 2 --output_dir TrainedLSTM/

# %%
#!textattack eval --num-examples 50 --model lstm-imdb

# %%
#!textattack eval --num-examples 50 --model bert-base-uncased-imdb

# %%
#!textattack eval --num-examples 50 --model TrainedLSTM/outputs/training/lstm-imdb-2020-08-13-21-25-20-085069

# %%
#!textattack attack --recipe textfooler --num-examples 5 --dataset-from-nlp imdb   --model lstm-imdb

# %%
#!textattack attack --recipe textfooler --num-examples 5 --dataset-from-nlp imdb  --model TrainedLSTM/outputs/training/lstm-imdb-2020-08-13-21-25-20-085069/

# %% [markdown]
# # Try Train multi_nli

# %%
'''
import numpy as np
import math

text = np.array(['a','bv','gh','poe','ksk','sasd','sdad','askdla','asdsdasd','asdasd','adasdasd'])
labels = np.array([1,2,0,1,0,2,1,2,1,0,1])
perc_ = math.ceil(len(text)*0.15)
print(perc_)
d = 'multi_nli'
if d is 'multi_nli':
  print("KEEEE")

eval_indices = np.random.RandomState(21).choice(np.arange(len(text)),size=perc_,)
eval_text = text[eval_indices]
eval_labels = labels[eval_indices]
text = np.delete(text,eval_indices)
labels = np.delete(labels,eval_indices)

print(text)
print(labels)
print(eval_text)
print(eval_labels)
'''
# Out:
# 2
# KEEEE
# ['a' 'bv' 'gh' 'poe' 'sdad' 'askdla' 'asdsdasd' 'asdasd' 'adasdasd']
# [1 2 0 1 1 2 1 0 1]
# ['sasd' 'ksk']
# [2 0]

# %%
#!textattack train --lr 3e-5 --model bert-base-uncased --dataset multi_nli --max-length 64 --batch-size 32 --epochs 3 --allowed-labels 0 1 2 --output_dir TrainedBertModels/
# Out:
# 2020-08-15 02:40:04.794509: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# textattack: WARNING: TextAttack's model training feature is in beta. Please report any issues on our Github page, https://github.com/QData/TextAttack/issues.
# textattack: Writing logs to TrainedBertModels/outputs/training/bert-base-uncased-multi_nli-2020-08-15-02-40-07-204982/log.txt.
# textattack: Loading nlp dataset multi_nli, split train.
# multi_nli
#
# False
# True
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/textattack-0.2.4-py3.6.egg/textattack/commands/train_model/train_args_helpers.py", line 135, in dataset_from_args
#     *dataset_args, split="dev"
# ...

# %% [markdown]
# # Try random attack

# %%
#!textattack attack --recipe random_nli --num-examples 2000 --dataset-from-nlp imdb  --model bert-base-uncased-imdb

# %%
#!textattack attack --recipe random_nli --num-examples 2000 --dataset-from-nlp snli  --model bert-base-uncased-snli

# %%
#!textattack attack --recipe textfooler --num-examples 2000 --dataset-from-nlp snli  --model bert-base-uncased-snli

# %%
#!textattack attack --recipe iga --num-examples 2 --dataset-from-nlp snli  --model bert-base-uncased-snli

# %% [markdown]
# # Create Train dataset frequency Corpus

# %%
#!ls ../snliData

# %%
#import pandas as pd
#train_snli_df = pd.read_csv('../snliData/snli_train_full.csv')

# %%
#train_snli_df

# %%
'''
import textattack
from textattack.attack_results import (
    FailedAttackResult,
    MaximizedAttackResult,
    SkippedAttackResult,
    SuccessfulAttackResult,
)
from textattack.goal_function_results import GoalFunctionResultStatus
from textattack.shared import AttackedText, utils
'''
# Out:
# '\nimport textattack\nfrom textattack.attack_results import (\n    FailedAttackResult,\n    MaximizedAttackResult,\n    SkippedAttackResult,\n    SuccessfulAttackResult,\n)\nfrom textattack.goal_function_results import GoalFunctionResultStatus\nfrom textattack.shared import AttackedText, utils\n'

# %%
#attack = textattack.shared.Attack

# %%
#a =textattack.shared.AttackedText("A person is training his horse for a competition.")

# %%
#import numpy as np
#np.random.choice(a.words)

# %%
#from textattack.transformations import WordSwapWordNet
#transformation = WordSwapWordNet()

# %%
'''
from textattack.constraints.pre_transformation import (
    InputColumnModification,
    RepeatModification,
    StopwordModification,
)
'''
# Out:
# '\nfrom textattack.constraints.pre_transformation import (\n    InputColumnModification,\n    RepeatModification,\n    StopwordModification,\n)\n'

# %%
#constraints = [RepeatModification(), StopwordModification()]

# %%
#from textattack.goal_functions import UntargetedClassification
#goal_function = UntargetedClassification(model)
