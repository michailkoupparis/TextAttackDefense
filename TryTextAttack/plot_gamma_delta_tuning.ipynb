# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/TryTextAttackAgain
# Out:
# /content/drive/My Drive/TryTextAttackAgain

# %%
# !ls
# Out:
# auc_delta_multi.png	InferSent_multi_nli_pretrained_GLOVE
# auc_delta_snli.png	inferSentSNLIModel.py
# BaseLoading.ipynb	InferSent_snli_pretrained_GLOVE
# corpus.py		multi_nli_train_word_freq.csv
# DefendBertGuide.ipynb	plot_gamma_delta_tuning.ipynb
# detect_adversarial.py	preprocess_datasets
# EvalBert.ipynb		prioritized.py
# fpr_delta_multi.png	__pycache__
# fpr_delta_snli.png	RunFull
# fpr_gamma_multi.png	snli_train_word_freq.csv
# fpr_gamma_snli.png	TextAttack
# freq_attacks_mnli.py	tpr_delta_multi.png
# freq_attacks_snli.py	tpr_delta_snli.png
# freq_stats.py		TrainedBertModels
# InferSent.ipynb		TrainNotebooks
# inferSentMultiModel.py	wandb

# %% [markdown]
# # SNLI f1 score

# %%
snli_perc = [0.693,6.353,7.836,8.925,9.805,10.728,11.644,12.202,12.822,13.157,13.736]
infersent_snli_f1_deltas = [0.9126,0.9202,0.8951,0.8734,0.8536,0.8443,0.8304,0.8310,0.8281,0.8284,0.8289]
bert_snli_f1_deltas = [0.927,0.933,0.913,0.896,0.878,0.868,0.856,0.856,0.855,0.854,0.853]
roberta_snli_f1_deltas = [0.9313,0.933,0.9145,0.8994,0.8843,0.8743,0.8610,0.8604,0.8594,0.8580,0.8582]


fig = plt.figure(figsize=(7,7))

plt.plot(snli_perc, infersent_snli_f1_deltas,marker ='H',  label='InferSent')
plt.plot(snli_perc,bert_snli_f1_deltas, marker='o',  label='Bert')
plt.plot(snli_perc, roberta_snli_f1_deltas, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.8, 1.00)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('F1 Score',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('f1_delta_snli.png')

# %% [markdown]
# ### SNli delta auc

# %%
snli_perc = [0.693,6.353,7.836,8.925,9.805,10.728,11.644,12.202,12.822,13.157,13.736]
bert_snli_auc_deltas = [0.747,0.829,0.808,0.786,0.748,0.748,0.728,0.728,0.725,0.744,0.724]
roberta_snli_auc_deltas = [0.760,0.8245,0.8028,0.7859,0.7641,0.7497,0.7332,0.7327,0.7296,0.7280,0.7282]
infersent_snli_auc_deltas = [0.6878,0.8057,0.7824,0.7510,0.7287,0.7163,0.7000,0.6996,0.6977,0.6983,0.6983]

fig = plt.figure(figsize=(7,7))

plt.plot(snli_perc, infersent_snli_auc_deltas,marker ='H',  label='InferSent')
plt.plot(snli_perc,bert_snli_auc_deltas, marker='o',  label='Bert')
plt.plot(snli_perc, roberta_snli_auc_deltas, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.50, 1.00)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('AUC',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('auc_delta_snli.png')

# %% [markdown]
# ## SNLI delta tpr

# %%
snli_perc = [0.693,6.353,7.836,8.925,9.805,10.728,11.644,12.202,12.822,13.157,13.736]
bert_snli_tpr = [0.511,0.749,0.764,0.765,0.763,0.756,0.743,0.741,0.741,0.742,0.741]
roberta_snli_tpr= [0.5338,0.7404,0.7528,0.7654,0.7625,0.7573,0.7498,0.7492,0.7492,0.7476,0.7476]
infersent_snli_tpr = [0.3769,0.7035,0.7259,0.7265,0.7224,0.7221,0.7194,0.7184,0.7218,0.7245,0.7238]

fig = plt.figure(figsize=(7,7))

plt.plot(snli_perc, infersent_snli_tpr,marker ='H',  label='InferSent')
plt.plot(snli_perc,bert_snli_tpr, marker='o',  label='Bert')
plt.plot(snli_perc, roberta_snli_tpr, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.2, 0.8)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('True Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig("tpr_delta_snli.png")

# %% [markdown]
# ## SNLI delta fpr

# %%
snli_perc = [0.693,6.353,7.836,8.925,9.805,10.728,11.644,12.202,12.822,13.157,13.736]
bert_snli_fpr = [0.002,0.055,0.097,0.128,0.157,0.173,0.191,0.190,0.192,0.194,0.194]
roberta_snli_fpr= [0.015,0.054,0.0924,0.1228,0.1485,0.1644,0.1849,0.1858,0.1875,0.1893,0.1890]
infersent_snli_fpr = [0.035,0.0718,0.1230,0.1609,0.1933,0.2084,0.2314,0.2290,0.2342,0.2344,0.2340]

fig = plt.figure(figsize=(7,7))

plt.plot(snli_perc, infersent_snli_fpr,marker ='H',  label='InferSent')
plt.plot(snli_perc,bert_snli_fpr, marker='o',  label='Bert')
plt.plot(snli_perc, roberta_snli_fpr, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0, 0.25)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('False Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig("fpr_delta_snli.png")

# %% [markdown]
# ### Gamma tuning

# %%
gamma_bert_snli = [0,0.2,0.4,0.45,0.5,0.55,0.6,0.8,0.85,0.9,1,]
bert_snli_fpr = [0.478,0.171,0.131,0.1212,0.112,0.104,0.0955,0.063,0.054,0.0432,0]

gamma_roberta_snli = [0,0.2,0.4,0.45,0.5,0.55,0.6,0.8,0.85,0.9,0.95,1,]
roberta_snli_tpr= [0.4378,0.1633,0.1272,0.1192,0.1109,0.1038,0.0971,0.0665,0.05811,0.04805,0.03495,0]

gamma_infersent_snli = [0,0.2,0.4,0.45,0.5,0.505,0.55,0.6,0.65,0.675,0.7,0.7125,0.8,0.9,1]
infersent_snli_fpr = [0.4230,0.1978,0.1318,0.1166,0.1099,0.0986,0.0881,0.0753,0.0630,0.0558,0.0511,0.0479,0.0210,0.0135,0]

fig = plt.figure(figsize=(7,7))

plt.plot(gamma_infersent_snli,infersent_snli_fpr ,marker ='H',  label='InferSent')
plt.plot(gamma_bert_snli,bert_snli_fpr, marker='o',  label='Bert')
plt.plot(gamma_roberta_snli, roberta_snli_tpr, marker='*',linestyle = '--',  label='Roberta')
plt.axhline(y=0.05,color='black',linestyle = '--', label='10%')
plt.axhline(y=0.10,color='black',linestyle = '--', label ='5%')

plt.grid()
plt.ylim(0.00, 0.50)
plt.xlabel('Confidence Limit($\gamma$)',size=15)
plt.ylabel('False Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('fpr_gamma_multi.png')

# %% [markdown]
# # MUlti

# %% [markdown]
# # Multi f1 score

# %%
multi_perc = [0.693,4.736,6.192,7.013,7.819,8.793,9.815,10.595,11.367,12.443,13.153]
infersent_multi_f1_deltas = [0.9445,0.9306,0.9097,0.8949,0.8810,0.8720,0.8636,0.8607,0.8592,0.8569,0.8566]
bert_multi_f1_deltas = [0.9436,0.9364,0.9211,0.9079,0.8974,0.8866,0.8789,0.8731,0.8720,0.8698,0.8698]
roberta_mutli_f1_deltas = [0.9488,0.9456,0.9333,0.9224,0.9136,0.9045,0.8967,0.8922,0.8919,0.8918,0.8919]


fig = plt.figure(figsize=(7,7))

plt.plot(multi_perc, infersent_multi_f1_deltas,marker ='H',  label='InferSent')
plt.plot(multi_perc,bert_multi_f1_deltas, marker='o',  label='Bert')
plt.plot(multi_perc, roberta_mutli_f1_deltas, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.8, 1.00)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('F1 Score',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('f1_delta_multi.png')

# %%
multi_perc = [0.693,4.736,6.192,7.013,7.819,8.793,9.815,10.595,11.367,12.443,13.153]
bert_multi_auc_deltas = [0.6649,0.7139,0.7020,0.6917,0.6808,0.6698,0.6590,0.6533,0.6530,0.6506,0.6505]
roberta_multi_auc_deltas = [0.6521,0.7301,0.7344,0.7351,0.7240,0.7189,0.7119,0.7006,0.7001,0.6989,0.6990]
infersent_multi_auc_deltas = [0.6032,0.6683,0.6562,0.6453,0.6298,0.6197,0.6094,0.6090,0.6098,0.6063,0.6061]

fig = plt.figure(figsize=(7,7))

plt.plot(multi_perc, infersent_multi_auc_deltas,marker ='H',  label='InferSent')
plt.plot(multi_perc,bert_multi_auc_deltas, marker='o',  label='Bert')
plt.plot(multi_perc, roberta_multi_auc_deltas, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.50, 1.00)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('AUC',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('auc_delta_multi.png')

# %% [markdown]
# ## TPrate

# %%
multi_perc = [0.693,4.736,6.192,7.013,7.819,8.793,9.815,10.595,11.367,12.443,13.153]
bert_multi_tpr = [0.3409,0.5516,0.5960,0.6229,0.6327,0.6350,0.6372,0.6361,0.6350,0.6369,0.6364]
roberta_multi_tpr= [0.3014,0.5494,0.5972,0.6359,0.6491,0.6590,0.6609,0.6534,0.6507,0.6504,0.6504]
infersent_multi_tpr = [0.2356,0.4733,0.5327,0.5626,0.5777,0.5864,0.5854,0.5901,0.5915,0.5932,0.5928]

fig = plt.figure(figsize=(7,7))

plt.plot(multi_perc, infersent_multi_tpr,marker ='H',  label='InferSent')
plt.plot(multi_perc,bert_multi_tpr, marker='o',  label='Bert')
plt.plot(multi_perc, roberta_multi_tpr, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0.2, 0.8)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('True Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('tpr_delta_multi.png')

# %% [markdown]
# # FPR rate

# %%
multi_perc = [0.693,4.736,6.192,7.013,7.819,8.793,9.815,10.595,11.367,12.443,13.153]
infer_mutli_fpr = [0.033,0.0615,0.1075,0.1375,0.1632,0.1793,0.1932,0.1984,0.2011,0.2050,0.2054]
bert_multi_fpr= [0.0020,0.0492,0.0848,0.1129,0.1329,0.1520,0.1653,0.1750,0.1771,0.1807,0.1805]
roberta_multi_fpr = [0.0185,0.042,0.0717,0.0968,0.1144,0.1317,0.1456,0.1523,0.1525,0.1527,0.1527]

fig = plt.figure(figsize=(7,7))

plt.plot(snli_perc, infer_mutli_fpr,marker ='H',  label='InferSent')
plt.plot(snli_perc,bert_multi_fpr, marker='o',  label='Bert')
plt.plot(snli_perc, roberta_multi_fpr, marker='*',  label='Roberta')

plt.grid()
plt.ylim(0, 0.25)
plt.xlabel('Frequency Limit($\delta$)',size=15)
plt.ylabel('False Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig("fpr_delta_multi.png")

# %% [markdown]
# ### Multi gamma tunning

# %%
gamma_bert_multi = [0,0.2,0.4,0.6,0.625,0.65,0.675,0.8,0.825,0.85,0.9,1]
bert_multi_fpr = [0.7284,0.2639,0.1758,0.1116,0.1049,0.09875,0.09275,0.0615,0.05385,0.04895,0.0421,0]

gamma_roberta_snli = [0,0.2,0.4,0.6,0.8,0.85,0.875,0.985,0.99,1]
roberta_snli_tpr= [0.6521,0.1754,0.15385,0.134,0.1117,0.102,0.0985,0.0576,0.04965,0.00005]

gamma_infersent_snli = [0,0.2,0.3,0.325,0.375,0.4,0.45,0.475,0.5,0.525,0.6,0.8,1]
infersent_snli_fpr = [0.644,0.2370,0.1500,0.1334,0.10275,0.0893,0.06835,0.0591,0.0505,0.0434,0.0277,0.0051,0]

fig = plt.figure(figsize=(7,7))

plt.plot(gamma_infersent_snli,infersent_snli_fpr ,marker ='H',  label='InferSent')
plt.plot(gamma_bert_multi,bert_multi_fpr, marker='o',  label='Bert')
plt.plot(gamma_roberta_snli, roberta_snli_tpr, marker='*',linestyle = '--',  label='Roberta')
plt.axhline(y=0.05,color='black',linestyle = '--', label='10%')
plt.axhline(y=0.10,color='black',linestyle = '--', label ='5%')

plt.grid()
plt.ylim(0.00, 0.75)
plt.xlabel('Confidence Limit($\gamma$)',size=15)
plt.ylabel('False Positive Rate',size=15)
plt.xticks(fontsize=14)

plt.legend(loc=0, prop={'size': 12})
#plt.show()
plt.savefig('fpr_gamma_multi.png')
